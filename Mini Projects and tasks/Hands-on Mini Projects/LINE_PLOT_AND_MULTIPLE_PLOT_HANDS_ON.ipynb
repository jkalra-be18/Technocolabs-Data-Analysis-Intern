# %%
import pandas as pd

# %%
unrate = pd.read_csv(r'C:\Users\Administrator\Downloads\unrate.csv')

# %%
unrate['DATE'] = pd.to_datetime(unrate['DATE'])

# %%
unrate.head(12)
# Out:
#          DATE  VALUE
# 0  1948-01-01    3.4
# 1  1948-02-01    3.8
# 2  1948-03-01    4.0
# 3  1948-04-01    3.9
# 4  1948-05-01    3.5
# 5  1948-06-01    3.6
# 6  1948-07-01    3.6
# 7  1948-08-01    3.9
# 8  1948-09-01    3.8
# 9  1948-10-01    3.7
# 10 1948-11-01    3.8
# 11 1948-12-01    4.0

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot()
plt.show()

# %%
x_values = unrate['DATE'].head(12)
y_values = unrate['VALUE'].head(12)

# %%
plt.plot(x_values, y_values)
plt.show()

# %%
plt.plot(x_values, y_values)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.plot(x_values, y_values)
plt.xticks(rotation = 90)
plt.xlabel('Month') 
plt.ylabel('Unemployment Rate')
plt.title('Monthly Unemployment Trends, 1948')
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)
ax1.plot(unrate['DATE'].head(12), unrate['VALUE'].head(12))
ax2.plot(unrate.DATE.loc[12:24], unrate.VALUE.loc[12:24])

plt.show()

# %%
fig = plt.figure(figsize = (12,12))
for i in range(4):
    ax = fig.add_subplot(1,5,i+1)
    start = i*12
    end = (i+1)*12
    ax.plot(unrate.DATE.loc[start:end], unrate.VALUE.loc[start:end])
    plt.xticks(rotation = 90)
plt.show()

# %%
unrate['MONTH'] = unrate['DATE'].dt.month

# %%
fig = plt.figure(figsize = (6,3))
plt.plot(unrate[0:12]['MONTH'], unrate[0:12]['VALUE'], c='red',label='1948')
plt.plot(unrate[12:24]['MONTH'], unrate[12:24]['VALUE'], c='blue', label='1949')
plt.legend(loc="upper left")
ax.set_title('Unemployment Trends for 3 years')
# Out:
# Text(0.5, 1, 'Unemployment Trends for 3 years')

# %%
fig = plt.figure(figsize = (12,5))
plt.plot(unrate[0:12]['MONTH'], unrate[0:12]['VALUE'], c='red',label='1948')
plt.plot(unrate[12:24]['MONTH'], unrate[12:24]['VALUE'], c='blue', label='1949')
plt.plot(unrate[24:36]['MONTH'], unrate[24:36]['VALUE'], c='green', label='1950')
plt.plot(unrate[36:48]['MONTH'], unrate[36:48]['VALUE'], c='orange', label='1951')
plt.plot(unrate[48:60]['MONTH'], unrate[48:60]['VALUE'], c='black', label='1952')
plt.legend(loc="upper left")
plt.xlabel('Month, Integer')
plt.ylabel('Unemployment Rate, Percent')
plt.title('Monthly Unemployment Trends, 1948-52')
# Out:
# Text(0.5, 1.0, 'Monthly Unemployment Trends, 1948-52')
